# %% [markdown]
# # Causal Reasoning In Large Language Models: CLadder

# %% [markdown]
# #### 1. Data Preparation

# %%
import pandas as pd
import json

dataset_path = "../data/cladder/cladder-v1-q-commonsense.json"
with open(dataset_path, "r") as f:
    data = json.load(f)
    
df = pd.DataFrame(data)
df.rename(columns={'given_info': 'info'}, inplace=True)

df = df[df['meta'].apply(lambda x: x.get('query_type') != 'backadj')].reset_index(drop=True)

# %%
index = 6700

print('Info: ', df.iloc[index]['info'])
print('Question: ', df.iloc[index]['question'])
print('Answer: ', df.iloc[index]['answer'])
print('Graph ID: ', df.iloc[index]['meta']['graph_id'])
print('Query type: ', df.iloc[index]['meta']['query_type'])
print('Rung: ', df.iloc[index]['meta']['rung'])
print('Formal form: ', df.iloc[index]['meta']['formal_form'])
print('Reasoning: ' , df.iloc[index]['reasoning'])
# Out:
# Info:  The overall probability of citrus intake is 18%. For patients not consuming citrus, the probability of scurvy is 68%. For patients consuming citrus, the probability of scurvy is 49%.
# Question:  Is scurvy less likely than no scurvy overall?
# Answer:  no
# Graph ID:  chain
# Query type:  marginal
# Rung:  1
# Formal form:  P(Y)
# Reasoning:  {'step0': 'Let X = eating citrus; V2 = vitmain C; Y = scurvy.', 'step1': 'X->V2,V2->Y', 'step2': 'P(Y)', 'step3': 'P(Y | X=1)*P(X=1) + P(Y | X=0)*P(X=0)', 'step4': 'P(X=1) = 0.18\nP(Y=1 | X=0) = 0.68\nP(Y=1 | X=1) = 0.49', 'step5': '0.18*0.49 - 0.82*0.68 = 0.65', 'end': '0.65 > 0'}

# %%
df['meta'][3]
# Out:
# {'story_id': 'alarm',
#  'graph_id': 'mediation',
#  'mediators': ['V2'],
#  'polarity': False,
#  'groundtruth': -0.2305349321780112,
#  'query_type': 'nie',
#  'rung': 3,
#  'formal_form': 'E[Y_{X=0, V2=1} - Y_{X=0, V2=0}]',
#  'given_info': {'p(Y | X, V2)': [[0.08430222457648505, 0.5394610521458689],
#    [0.4061509701126924, 0.8620283206949241]],
#   'p(V2 | X)': [0.7416866188819116, 0.23519324071521291]},
#  'estimand': '\\sum_{V2 = v} P(Y=1|X =0,V2 = v)*[P(V2 = v | X = 1) − P(V2 = v | X = 0)]',
#  'treatment': 'X',
#  'outcome': 'Y',
#  'model_id': 0}

# %%
df_new = df.copy()
meta_df = df_new['meta'].apply(pd.Series)
meta_df
df_new = pd.concat([df_new, meta_df], axis = 1)
df_new = df_new.drop('meta', axis = 1)
df_new.rename(columns={'given_info': 'given_info_meta', 'given_info': 'given_info'}, inplace=True)

# %%
df_sampled = df_new.sample(n = 1000, random_state=25)
print(len(df_sampled))
# Out:
# 1000

# %%
column_names = ['answer', 'query_type', 'answer', 'graph_id', 'rung', 'query_type', 'story_id', 'polarity']

for column_name in column_names:
    print(df_sampled[column_name].value_counts())
    print(df_new[column_name]. value_counts())
    print('----------------------------------')
# Out:
# answer
# no     504
# yes    496
# Name: count, dtype: int64
# answer
# yes    4345
# no     4345
# Name: count, dtype: int64
# ----------------------------------
# query_type
# marginal              209
# ate                   174
# correlation           174
# ett                   138
# det-counterfactual     95
# nie                    92
# nde                    73
# collider_bias          23
# exp_away               22
# Name: count, dtype: int64
# query_type
# marginal              1702
# ate                   1518
# correlation           1518
# ett                   1288
# nie                    874
# det-counterfactual     870
# nde                    552
# exp_away               184
# collider_bias          184
# Name: count, dtype: int64
# ----------------------------------
# answer
# no     504
# yes    496
# Name: count, dtype: int64
# answer
# yes    4345
# no     4345
# Name: count, dtype: int64
# ----------------------------------
# graph_id
# mediation      197
# arrowhead      188
# confounding    106
# diamond        105
# IV             102
# chain           85
# fork            84
# collision       74
# frontdoor       32
# diamondcut      27
# Name: count, dtype: int64
# graph_id
# arrowhead      1848
# mediation      1752
# IV              920
# confounding     864
# fork            800
# diamond         738
# chain           738
# collision       552
# frontdoor       262
# diamondcut      216
# Name: count, dtype: int64
# ----------------------------------
# rung
# 1    405
# 3    398
# 2    197
# Name: count, dtype: int64
# rung
# 3    3584
# 1    3404
# 2    1702
# Name: count, dtype: int64
# ----------------------------------
# query_type
# marginal              209
# ate                   174
# correlation           174
# ett                   138
# det-counterfactual     95
# nie                    92
# nde                    73
# collider_bias          23
# exp_away               22
# Name: count, dtype: int64
# query_type
# marginal              1702
# ate                   1518
# correlation           1518
# ett                   1288
# nie                    874
# det-counterfactual     870
# nde                    552
# exp_away               184
# collider_bias          184
# Name: count, dtype: int64
# ----------------------------------
# story_id
# penguin                   40
# obesity_mortality         39
# blood_pressure            38
# floor_wet                 38
# simpson_hospital          37
# encouagement_program      35
# firing_squad              35
# nature_vs_nurture         34
# smoking_frontdoor         32
# vaccine_kills             32
# smoking_gene_cancer       31
# orange_scurvy             30
# neg_mediation             30
# alarm                     29
# gender_admission_state    29
# smoking_tar_cancer        28
# gender_pay                28
# simpson_vaccine           28
# firing_employee           27
# college_salary            27
# smoke_birthWeight         27
# celebrity                 26
# candle                    25
# gender_admission          25
# price                     25
# college_wage              23
# forest_fire               21
# simpson_kidneystone       21
# cholesterol               20
# simpson_drug              20
# getting_late              20
# hospitalization           20
# getting_tanned            18
# tax_smoke_birthWeight     18
# elite_students            17
# water_cholera             16
# man_in_relationship       11
# Name: count, dtype: int64
# story_id
# gender_admission_state    308
# smoking_gene_cancer       308
# smoke_birthWeight         308
# obesity_mortality         308
# nature_vs_nurture         308
# gender_pay                308
# blood_pressure            292
# neg_mediation             292
# gender_admission          292
# encouagement_program      292
# alarm                     292
# penguin                   292
# smoking_frontdoor         262
# floor_wet                 246
# college_salary            246
# smoking_tar_cancer        246
# vaccine_kills             246
# orange_scurvy             246
# firing_squad              246
# simpson_drug              216
# simpson_vaccine           216
# firing_employee           216
# simpson_kidneystone       216
# simpson_hospital          216
# getting_late              200
# forest_fire               200
# getting_tanned            200
# candle                    200
# tax_smoke_birthWeight     184
# water_cholera             184
# price                     184
# cholesterol               184
# college_wage              184
# man_in_relationship       138
# hospitalization           138
# elite_students            138
# celebrity                 138
# Name: count, dtype: int64
# ----------------------------------
# polarity
# False    502
# True     498
# Name: count, dtype: int64
# polarity
# True     4360
# False    4330
# Name: count, dtype: int64
# ----------------------------------

# %% [markdown]
# #### 2. Add models to dataframe for storing results

# %%
df_cladder = df_sampled.copy()

# %%
def add_column(df, model_name):   
    if model_name not in df.columns: 
        df[model_name] = None
    else:
        print(model_name + " already exists in Dataframe!")


column_names = ['gpt-4o-mini']


for c in column_names:
    add_column(df_cladder, c)
    add_column(df_cladder, c +'_reasoning')
    

df_cladder = df_cladder.reset_index(drop=True)

# %%
# Check out index 550!

index = 300
print(df_cladder.iloc[index]['info'])
print(df_cladder.iloc[index]['question'])
print(df_cladder.iloc[index]['answer'])
print(df_cladder.iloc[index]['reasoning'])
# Out:
# For individuals who are not male and applicants to a non-competitive department, the probability of admission acceptance is 63%. For individuals who are not male and applicants to a competitive department, the probability of admission acceptance is 36%. For individuals who are male and applicants to a non-competitive department, the probability of admission acceptance is 60%. For individuals who are male and applicants to a competitive department, the probability of admission acceptance is 37%. For individuals who are not male and out-of-state residents, the probability of competitive department is 67%. For individuals who are not male and in-state residents, the probability of competitive department is 28%. For individuals who are male and out-of-state residents, the probability of competitive department is 89%. For individuals who are male and in-state residents, the probability of competitive department is 57%. The overall probability of in-state residency is 99%.
# Does gender positively affect admission status through department competitiveness?
# no
# {'step0': 'Let V2 = residency status; X = gender; V3 = department competitiveness; Y = admission status.', 'step1': 'X->V3,V2->V3,X->Y,V2->Y,V3->Y', 'step2': 'E[Y_{X=0, V3=1} - Y_{X=0, V3=0}]', 'step3': '\\sum_{V3=v} [\\sum_{V2=k} P(Y=1|X=0,V3=v)*[P(V3=v|X=1,V2=k)-P(V3=v|X=0,V2=k)]*P(V2=k)]', 'step4': 'P(Y=1 | X=0, V3=0) = 0.63\nP(Y=1 | X=0, V3=1) = 0.36\nP(Y=1 | X=1, V3=0) = 0.60\nP(Y=1 | X=1, V3=1) = 0.37\nP(V3=1 | X=0, V2=0) = 0.67\nP(V3=1 | X=0, V2=1) = 0.28\nP(V3=1 | X=1, V2=0) = 0.89\nP(V3=1 | X=1, V2=1) = 0.57\nP(V2=1) = 0.99', 'step5': '0.99 * 0.36 * (0.57 - 0.89)+ 0.01 * 0.36 * (0.28 - 0.67)= -0.08', 'end': '-0.08 < 0'}

# %%
df_cladder.iloc[index]
# Out:
# question_id                                                           6432
# desc_id                  gender_admission_state-arrowhead-nie-model562-...
# info                     For individuals who are not male and applicant...
# question                 Does gender positively affect admission status...
# answer                                                                  no
# reasoning                {'step0': 'Let V2 = residency status; X = gend...
# story_id                                            gender_admission_state
# graph_id                                                         arrowhead
# treated                                                                NaN
# result                                                                 NaN
# polarity                                                              True
# groundtruth                                                       -0.07786
# query_type                                                             nie
# rung                                                                     3
# formal_form                               E[Y_{X=0, V3=1} - Y_{X=0, V3=0}]
# given_info               {'p(Y | X, V3)': [[0.6308051460036148, 0.36397...
# estimand                 \sum_{V3=v} [\sum_{V2=k} P(Y=1|X=0,V3=v)*[P(V3...
# treatment                                                                X
# outcome                                                                  Y
# model_id                                                               562
# mediators                                                             [V3]
# baseline                                                               NaN
# collider                                                               NaN
# action                                                                 NaN
# gpt-4o-mini                                                           None
# gpt-4o-mini_reasoning                                                 None
# Name: 300, dtype: object

# %% [markdown]
# ### 3. Implement Tree of Thoughts

# %%
from openai import OpenAI
from constants import OPENAI_API_KEY
client = OpenAI(api_key=OPENAI_API_KEY) 

def input_output(prompt, model='gpt-4o-mini', temperature=1.0):

    prompt_question = prompt
    completion = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "user", "content": prompt_question}
        ],
        temperature=temperature,
    )
    
    model_answer = completion.choices[0].message.content
    return model_answer

# %%
import re

def extract_option(input_string):
    """
    Extracts the content inside the last pair of curly braces from a string.

    Args:
        input_string: The string containing the curly braces.

    Returns:
        A string representing the content inside the last pair of curly braces, 
        or None if no curly braces are found.
    """
    try:
        start_index = input_string.rfind("{")
        end_index = input_string.rfind("}")

        if start_index == -1 or end_index == -1 or start_index >= end_index:
            return None

        # Extract the content inside the last pair of curly braces
        return input_string[start_index + 1 : end_index].strip()

    except Exception as e:
        print(f"An error occurred: {e}")
        return None

def extract_options(input_string):
    """
    Extracts the list of options from the last set of curly brackets in the input string.
    Flattens any multiline content within the curly brackets into a single line and
    returns only the content inside quotation marks as a list.

    Args:
        input_string (str): The string containing the list.

    Returns:
        list: A list of extracted options, or None if no valid list is found.
    """
    try:
        start_index = input_string.rfind("{")
        end_index = input_string.rfind("}")
        if start_index == -1 or end_index == -1 or start_index >= end_index:
            return None

        # Extract the content between the curly brackets
        content = input_string[start_index + 1:end_index]
        # Flatten the multiline content into a single line
        content = " ".join(content.splitlines())
        content = " ".join(content.split())  # remove extra spaces

        # Use regex to extract only the quoted strings
        elements = re.findall(r'"([^"]*)"', content)
        return elements

    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
text = ''' Options: {
  "E[prisoner | do(captain = release)] - E[prisoner | do(captain = execute)]", 
  "P(prisoner = alive | do(captain = release)) - P(prisoner = alive | do(captain = execute))", 
  "E[prisoner_life]_{do(captain = release)} - E[prisoner_life]_{do(captain = execute)}"
}'''
extract_options(text)
# Out:
# []

# %%
text = '''
"Step 1) Extract the causal graph: 
Citrus Intake -> Scurvy, No Citrus -> Scurvy

Step 2) Determine the query type: 
"average treatment effect"

Step 3) Formalize the query: 
To analyze the average treatment effect of citrus intake on the probability of scurvy, we want to compare the probabilities of scurvy under different conditions of citrus consumption. The three possible formalizations could be:

1) P(Scurvy | do(Citrus Intake)) - P(Scurvy | do(No Citrus))
2) E[Scurvy | do(Citrus Intake)] - E[Scurvy | do(No Citrus)]
3) P(Scurvy | do(Citrus Intake)) - P(Scurvy)

List of options:
{"P(Scurvy | do(Citrus Intake)) - P(Scurvy | do(No Citrus))", "E[Scurvy | do(Citrus Intake)] - E[Scurvy | do(No Citrus)]", "P(Scurvy | do(Citrus Intake)) - P(Scurvy)"}
'''

extract_options(text)
# Out:
# ['P(Scurvy | do(Citrus Intake)) - P(Scurvy | do(No Citrus))',
#  'E[Scurvy | do(Citrus Intake)] - E[Scurvy | do(No Citrus)]',
#  'P(Scurvy | do(Citrus Intake)) - P(Scurvy)']

# %%
text = 'Answer: {P(C) = 0.18; P(S | ~C) = 0.68; P(S | C) = 0.49}'
extract_option(text)

# %%
import re

def extract_yes_or_no(input_string):
    # Using regular expression to find all occurrences of 'yes' or 'no' in the input string
    matches = re.findall(r'\b(?:yes|no)\b', input_string, re.IGNORECASE)

    if matches:
        # Return the last matched text in lowercase
        return matches[-1].lower()
    else:
        # Return None if no match is found
        return None

# %%
causal_cot_prompts = [
  "Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.",
  "Step 2) Determine the query type: Identify the type of query implied by the main question. Choices include 'marginal probability', 'conditional probability', 'explaining away effect', 'backdoor adjustment set', 'average treatment effect', 'collider bias', 'normal counterfactual question', 'average treatment effect on treated', 'natural direct effect' or 'natural indirect effect'. Your answer should only be a term from the list above, enclosed in 'quotation marks'.",
  "Step 3) Formalize the query: Translate the query into its formal mathematical expression based on its type, utilizing the 'do(·)' notation or counterfactual notations as needed.",
  "Step 4) Gather all relevant data: Extract all the available data. Your answer should contain nothing but marginal probabilities and conditional probabilities in the form 'P(...)=...' or 'P(...|...)=...', each probability being separated by a semicolon. Stick to the previously mentioned denotations for the variables.",
  "Step 5) Deduce the estimand using causal inference: Given all the information above, deduce the estimand using skills such as do-calculus, counterfactual prediction, and the basics of probabilities.",
  "Step 6) Calculate the estimand: Insert the relevant data in Step 4 into the estimand, perform basic arithmetic calculations, and derive the final answer. Answer with yes or no in the end"
]

generate_single_prompt = '''
Question: {question} -> {causal_cot_prompt} -> Answer this and put it in curly brackets like Answer: {{X}}
'''

generate_prompt = '''
Question: {question} -> {causal_cot_prompt} -> 
-> Generate {num_generated_options} possible options for this, and then put all the options in a list, each option being a string, like
Options: {{"X", "X", "X"}}. Make sure this is in a single line!
'''

evaluate_prompt = '''
Question: {question} -> Options: {new_thoughts} -> 
-> Assign a score between 1 - 10 for each option in Options: depending on how well it answers the question (10 being the highest or the best), then put the score into a list, each score being a string, like
Options: {{"X", "X", "X"}}. Make sure this is in a single line!
'''

def generate_thoughts(model, question, num_generated_options, step): #TODO: Extend to cases when there is more than 1 selected 
    
    prompt = generate_prompt.format(question=question, causal_cot_prompt=causal_cot_prompts[step], num_generated_options=num_generated_options)
    answer_prompt = input_output(prompt, model=model)
    print('Answer prompt: ', answer_prompt)
    answers = extract_options(answer_prompt)
    
    return answers

def generate_single_thought(model, question, step): # For cases when step is skipped
    
    prompt = generate_single_prompt.format(question=question, causal_cot_prompt=causal_cot_prompts[step])
    answer_prompt = input_output(prompt, model=model)

    print('Single generate prompt: ', prompt)
    print('Single answer prompt: ', answer_prompt)
    
    answers = extract_option(answer_prompt)
    print('Single answers thought: ', answers)
    
    return answers


def evaluate_thoughts(model, question, new_thoughts):
    
    prompt = evaluate_prompt.format(question=question, new_thoughts=str(new_thoughts))
    answer_prompt = input_output(prompt, model=model)
    print('Evaluate prompt: ', answer_prompt)

    answer = extract_options(answer_prompt)
    integer_list = [int(x) for x in answer]
    return integer_list

question = "The overall probability of citrus intake is 18%. For patients not consuming citrus, the probability of scurvy is 68%. For patients consuming citrus, the probability of scurvy is 49%. Is scurvy less likely than no scurvy overall?"
question

#generated_thoughts = generate_thoughts('gpt-4o-mini', question, 3, 0)
#print("FINAL ANSWER: ", evaluate_thoughts('gpt-4o-mini', question, generated_thoughts))
# Out:
# 'The overall probability of citrus intake is 18%. For patients not consuming citrus, the probability of scurvy is 68%. For patients consuming citrus, the probability of scurvy is 49%. Is scurvy less likely than no scurvy overall?'

# %%
def search_algorithm(new_thoughts, ids, scores, n_select_sample):
    selected_ids = sorted(ids, key=lambda x: scores[x], reverse=True)[:n_select_sample] # Take top n_select_sample from list based on scores
    select_new_thoughts = [new_thoughts[select_id] for select_id in selected_ids]  
    return select_new_thoughts

# %%
def tree_of_thoughts(model, question, num_generated_options, num_selected_options):
    
    thoughts = ['']    
    question = 'Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:' + '\n' + question

    for step in range(6):

        print('STEP NUMBER: ', step)
        
        if step == 3 or step == 5: # Skipping steps 4 and 6 from the CausalCOT prompts
            print('SKIPPING THIS STEP: ', step) 
            single_thought = generate_single_thought(model, question, step)
            question = question + "\n" +  causal_cot_prompts[step] +  "\n" + str(single_thought)

            print('QUESTION SO FAR: ', question)
            print('\n' + '-------' + '\n')
        
        else:
            
            new_thoughts = generate_thoughts(model, question, num_generated_options, step)
            ids = list(range(len(new_thoughts)))

            # Thought Generation
            print('(Step 1) New Thoughts: ', new_thoughts)
            print('(Step 1) ids ', ids)

            # Thought Evaluation
            scores = evaluate_thoughts(model, question, new_thoughts)
            print('(Step 2) Scores: ', scores)

            # Thought Selection (Search Algorithm) -> Here, we only select one highest scoring thought and progress
            # to the next step
            selected_thought = search_algorithm(new_thoughts, ids, scores, num_selected_options)
            print('(Step 3) Selected thought: ', selected_thought)

            # TODO: Change this later if multiple thoughts are selected
            question = question + "\n" +  causal_cot_prompts[step] +  "\n" + str(selected_thought[0])

            print('QUESTION SO FAR: ', question)
            print('\n' + '-------' + '\n')

    
    return question
            

#question = "The overall probability of citrus intake is 18%. For patients not consuming citrus, the probability of scurvy is 68%. For patients consuming citrus, the probability of scurvy is 49%. Is scurvy less likely than no scurvy overall?"
#tree_of_thoughts('gpt-4o-mini', question, 3, 1)

# %%
def run_openai_tree_of_thoughts(df, model_col_name, model, min_range, max_range, temperature=1.0, overwrite=False):
    
    if model_col_name not in df.columns:
        raise KeyError(model_col_name + " : Column name doesn't exist!")
    
    for i in range(min_range, max_range):

        if df.iloc[i][model_col_name] is None or overwrite == True:
            
            prompt_question =  'Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:' + '\n' + df.iloc[i]['info'] + " " + df.iloc[i]['question']
            prompt_answer = tree_of_thoughts(model, prompt_question, 3, 1)
            extracted_answer = extract_yes_or_no(prompt_answer)


            print('PROMPT ANSWER: ', prompt_answer)
            print('EXTRACTED ANSWER: ', extracted_answer)
            
            df.at[i, model_col_name] = extracted_answer
            df.at[i, model_col_name + '_reasoning'] = prompt_answer
            print('Generation completed: ', i)

        else:
        
            print('Skipping: ', i)    


run_openai_tree_of_thoughts(df_cladder, model_col_name='gpt-4o-mini', model='gpt-4o-mini', overwrite=True, min_range=270, max_range=300)
# Out:
# STEP NUMBER:  0
# Answer prompt:  Options: {"captain_order -> prisoner_outcome, prisoner_outcome -> prisoner_death", "captain_order -> prisoner_death, prisoner_release -> prisoner_death", "captain_order -> prisoner_release, prisoner_release -> prisoner_death"}
# (Step 1) New Thoughts:  ['captain_order -> prisoner_outcome, prisoner_outcome -> prisoner_death', 'captain_order -> prisoner_death, prisoner_release -> prisoner_death', 'captain_order -> prisoner_release, prisoner_release -> prisoner_death']
# (Step 1) ids  [0, 1, 2]
# Evaluate prompt:  Options: {"10", "8", "6"}
# (Step 2) Scores:  [10, 8, 6]
# (Step 3) Selected thought:  ['captain_order -> prisoner_outcome, prisoner_outcome -> prisoner_death']
# QUESTION SO FAR:  Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# The overall probability of the captain's order to execute the prisoner is 18%. For captains who release prisoners, the probability of the prisoner's death is 33%. For captains who execute prisoners, the probability of the prisoner's death is 81%. Is the prisoner's death more likely than the prisoner being alive overall?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# captain_order -> prisoner_outcome, prisoner_outcome -> prisoner_death
#
# -------
#
# STEP NUMBER:  1
# Answer prompt:  Options: {"marginal probability", "conditional probability", "explaining away effect"}
# (Step 1) New Thoughts:  ['marginal probability', 'conditional probability', 'explaining away effect']
# (Step 1) ids  [0, 1, 2]
# Evaluate prompt:  captain_order -> prisoner_outcome, prisoner_outcome -> prisoner_death -> Options: ['marginal probability', 'conditional probability', 'explaining away effect'] ->
# -> Assign a score between 1 - 10 for each option in Options: {"7", "9", "5"}.
# (Step 2) Scores:  [7, 9, 5]
# (Step 3) Selected thought:  ['conditional probability']
# QUESTION SO FAR:  Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# The overall probability of the captain's order to execute the prisoner is 18%. For captains who release prisoners, the probability of the prisoner's death is 33%. For captains who execute prisoners, the probability of the prisoner's death is 81%. Is the prisoner's death more likely than the prisoner being alive overall?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# captain_order -> prisoner_outcome, prisoner_outcome -> prisoner_death
# Step 2) Determine the query type: Identify the type of query implied by the main question. Choices include 'marginal probability', 'conditional probability', 'explaining away effect', 'backdoor adjustment set', 'average treatment effect', 'collider bias', 'normal counterfactual question', 'average treatment effect on treated', 'natural direct effect' or 'natural indirect effect'. Your answer should only be a term from the list above, enclosed in 'quotation marks'.
# conditional probability
#
# -------
#
# STEP NUMBER:  2
# Answer prompt:  Options: {"P(prisoner_death | captain_order = execute)", "P(prisoner_death | captain_order = release)", "P(prisoner_death)"}
# (Step 1) New Thoughts:  ['P(prisoner_death | captain_order = execute)', 'P(prisoner_death | captain_order = release)', 'P(prisoner_death)']
# (Step 1) ids  [0, 1, 2]
# Evaluate prompt:  Options: {"10", "10", "5"}
# (Step 2) Scores:  [10, 10, 5]
# (Step 3) Selected thought:  ['P(prisoner_death | captain_order = execute)']
# QUESTION SO FAR:  Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# The overall probability of the captain's order to execute the prisoner is 18%. For captains who release prisoners, the probability of the prisoner's death is 33%. For captains who execute prisoners, the probability of the prisoner's death is 81%. Is the prisoner's death more likely than the prisoner being alive overall?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# captain_order -> prisoner_outcome, prisoner_outcome -> prisoner_death
# Step 2) Determine the query type: Identify the type of query implied by the main question. Choices include 'marginal probability', 'conditional probability', 'explaining away effect', 'backdoor adjustment set', 'average treatment effect', 'collider bias', 'normal counterfactual question', 'average treatment effect on treated', 'natural direct effect' or 'natural indirect effect'. Your answer should only be a term from the list above, enclosed in 'quotation marks'.
# conditional probability
# Step 3) Formalize the query: Translate the query into its formal mathematical expression based on its type, utilizing the 'do(·)' notation or counterfactual notations as needed.
# P(prisoner_death | captain_order = execute)
#
# -------
#
# STEP NUMBER:  3
# SKIPPING THIS STEP:  3
# Single generate prompt:
# Question: Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# The overall probability of the captain's order to execute the prisoner is 18%. For captains who release prisoners, the probability of the prisoner's death is 33%. For captains who execute prisoners, the probability of the prisoner's death is 81%. Is the prisoner's death more likely than the prisoner being alive overall?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# captain_order -> prisoner_outcome, prisoner_outcome -> prisoner_death
# Step 2) Determine the query type: Identify the type of query implied by the main question. Choices include 'marginal probability', 'conditional probability', 'explaining away effect', 'backdoor adjustment set', 'average treatment effect', 'collider bias', 'normal counterfactual question', 'average treatment effect on treated', 'natural direct effect' or 'natural indirect effect'. Your answer should only be a term from the list above, enclosed in 'quotation marks'.
# conditional probability
# Step 3) Formalize the query: Translate the query into its formal mathematical expression based on its type, utilizing the 'do(·)' notation or counterfactual notations as needed.
# P(prisoner_death | captain_order = execute) -> Step 4) Gather all relevant data: Extract all the available data. Your answer should contain nothing but marginal probabilities and conditional probabilities in the form 'P(...)=...' or 'P(...|...)=...', each probability being separated by a semicolon. Stick to the previously mentioned denotations for the variables. -> Answer this and put it in curly brackets like Answer: {X}
#
# Single answer prompt:  P(captain_order = execute) = 0.18; P(captain_order = release) = 0.82; P(prisoner_death | captain_order = execute) = 0.81; P(prisoner_death | captain_order = release) = 0.33; P(prisoner_outcome | captain_order = execute) = 1; P(prisoner_outcome | captain_order = release) = 1;
#
# Answer: {P(captain_order = execute) = 0.18; P(captain_order = release) = 0.82; P(prisoner_death | captain_order = execute) = 0.81; P(prisoner_death | captain_order = release) = 0.33; P(prisoner_outcome | captain_order = execute) = 1; P(prisoner_outcome | captain_order = release) = 1}
# Single answers thought:  P(captain_order = execute) = 0.18; P(captain_order = release) = 0.82; P(prisoner_death | captain_order = execute) = 0.81; P(prisoner_death | captain_order = release) = 0.33; P(prisoner_outcome | captain_order = execute) = 1; P(prisoner_outcome | captain_order = release) = 1
# QUESTION SO FAR:  Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# The overall probability of the captain's order to execute the prisoner is 18%. For captains who release prisoners, the probability of the prisoner's death is 33%. For captains who execute prisoners, the probability of the prisoner's death is 81%. Is the prisoner's death more likely than the prisoner being alive overall?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# captain_order -> prisoner_outcome, prisoner_outcome -> prisoner_death
# Step 2) Determine the query type: Identify the type of query implied by the main question. Choices include 'marginal probability', 'conditional probability', 'explaining away effect', 'backdoor adjustment set', 'average treatment effect', 'collider bias', 'normal counterfactual question', 'average treatment effect on treated', 'natural direct effect' or 'natural indirect effect'. Your answer should only be a term from the list above, enclosed in 'quotation marks'.
# conditional probability
# Step 3) Formalize the query: Translate the query into its formal mathematical expression based on its type, utilizing the 'do(·)' notation or counterfactual notations as needed.
# P(prisoner_death | captain_order = execute)
# Step 4) Gather all relevant data: Extract all the available data. Your answer should contain nothing but marginal probabilities and conditional probabilities in the form 'P(...)=...' or 'P(...|...)=...', each probability being separated by a semicolon. Stick to the previously mentioned denotations for the variables.
# P(captain_order = execute) = 0.18; P(captain_order = release) = 0.82; P(prisoner_death | captain_order = execute) = 0.81; P(prisoner_death | captain_order = release) = 0.33; P(prisoner_outcome | captain_order = execute) = 1; P(prisoner_outcome | captain_order = release) = 1
#
# -------
#
# STEP NUMBER:  4
# Answer prompt:  Options: {"P(prisoner_death) > 0.5", "P(prisoner_death) < 0.5", "P(prisoner_death) = 0.5"}
# (Step 1) New Thoughts:  ['P(prisoner_death) > 0.5', 'P(prisoner_death) < 0.5', 'P(prisoner_death) = 0.5']
# (Step 1) ids  [0, 1, 2]
# Evaluate prompt:  Options: {"10", "1", "1"}
# (Step 2) Scores:  [10, 1, 1]
# (Step 3) Selected thought:  ['P(prisoner_death) > 0.5']
# QUESTION SO FAR:  Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# The overall probability of the captain's order to execute the prisoner is 18%. For captains who release prisoners, the probability of the prisoner's death is 33%. For captains who execute prisoners, the probability of the prisoner's death is 81%. Is the prisoner's death more likely than the prisoner being alive overall?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# captain_order -> prisoner_outcome, prisoner_outcome -> prisoner_death
# Step 2) Determine the query type: Identify the type of query implied by the main question. Choices include 'marginal probability', 'conditional probability', 'explaining away effect', 'backdoor adjustment set', 'average treatment effect', 'collider bias', 'normal counterfactual question', 'average treatment effect on treated', 'natural direct effect' or 'natural indirect effect'. Your answer should only be a term from the list above, enclosed in 'quotation marks'.
# conditional probability
# Step 3) Formalize the query: Translate the query into its formal mathematical expression based on its type, utilizing the 'do(·)' notation or counterfactual notations as needed.
# P(prisoner_death | captain_order = execute)
# Step 4) Gather all relevant data: Extract all the available data. Your answer should contain nothing but marginal probabilities and conditional probabilities in the form 'P(...)=...' or 'P(...|...)=...', each probability being separated by a semicolon. Stick to the previously mentioned denotations for the variables.
# P(captain_order = execute) = 0.18; P(captain_order = release) = 0.82; P(prisoner_death | captain_order = execute) = 0.81; P(prisoner_death | captain_order = release) = 0.33; P(prisoner_outcome | captain_order = execute) = 1; P(prisoner_outcome | captain_order = release) = 1
# Step 5) Deduce the estimand using causal inference: Given all the information above, deduce the estimand using skills such as do-calculus, counterfactual prediction, and the basics of probabilities.
# P(prisoner_death) > 0.5
#
# -------
#
# STEP NUMBER:  5
# SKIPPING THIS STEP:  5
# Single generate prompt:
# Question: Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# The overall probability of the captain's order to execute the prisoner is 18%. For captains who release prisoners, the probability of the prisoner's death is 33%. For captains who execute prisoners, the probability of the prisoner's death is 81%. Is the prisoner's death more likely than the prisoner being alive overall?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# captain_order -> prisoner_outcome, prisoner_outcome -> prisoner_death
# Step 2) Determine the query type: Identify the type of query implied by the main question. Choices include 'marginal probability', 'conditional probability', 'explaining away effect', 'backdoor adjustment set', 'average treatment effect', 'collider bias', 'normal counterfactual question', 'average treatment effect on treated', 'natural direct effect' or 'natural indirect effect'. Your answer should only be a term from the list above, enclosed in 'quotation marks'.
# conditional probability
# Step 3) Formalize the query: Translate the query into its formal mathematical expression based on its type, utilizing the 'do(·)' notation or counterfactual notations as needed.
# P(prisoner_death | captain_order = execute)
# Step 4) Gather all relevant data: Extract all the available data. Your answer should contain nothing but marginal probabilities and conditional probabilities in the form 'P(...)=...' or 'P(...|...)=...', each probability being separated by a semicolon. Stick to the previously mentioned denotations for the variables.
# P(captain_order = execute) = 0.18; P(captain_order = release) = 0.82; P(prisoner_death | captain_order = execute) = 0.81; P(prisoner_death | captain_order = release) = 0.33; P(prisoner_outcome | captain_order = execute) = 1; P(prisoner_outcome | captain_order = release) = 1
# Step 5) Deduce the estimand using causal inference: Given all the information above, deduce the estimand using skills such as do-calculus, counterfactual prediction, and the basics of probabilities.
# P(prisoner_death) > 0.5 -> Step 6) Calculate the estimand: Insert the relevant data in Step 4 into the estimand, perform basic arithmetic calculations, and derive the final answer. Answer with yes or no in the end -> Answer this and put it in curly brackets like Answer: {X}
#
# Single answer prompt:  Step 6) Calculate the estimand:
#
# To find \( P(prisoner\_death) \), we use the law of total probability:
#
# \[
# P(prisoner\_death) = P(prisoner\_death | captain\_order = execute) \cdot P(captain\_order = execute) + P(prisoner\_death | captain\_order = release) \cdot P(captain\_order = release)
# \]
#
# Substituting the known values:
#
# \[
# P(prisoner\_death) = (0.81 \cdot 0.18) + (0.33 \cdot 0.82)
# \]
#
# Calculating each component:
#
# \[
# 0.81 \cdot 0.18 = 0.1458
# \]
# \[
# 0.33 \cdot 0.82 = 0.2706
# \]
#
# Adding these together:
#
# \[
# P(prisoner\_death) = 0.1458 + 0.2706 = 0.4164
# \]
#
# Now we check if \( P(prisoner\_death) > 0.5 \):
#
# \[
# 0.4164 > 0.5 \text{ is } \text{False}
# \]
#
# Thus, the final answer is: Answer: {no}
# Single answers thought:  no
# QUESTION SO FAR:  Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# The overall probability of the captain's order to execute the prisoner is 18%. For captains who release prisoners, the probability of the prisoner's death is 33%. For captains who execute prisoners, the probability of the prisoner's death is 81%. Is the prisoner's death more likely than the prisoner being alive overall?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# captain_order -> prisoner_outcome, prisoner_outcome -> prisoner_death
# Step 2) Determine the query type: Identify the type of query implied by the main question. Choices include 'marginal probability', 'conditional probability', 'explaining away effect', 'backdoor adjustment set', 'average treatment effect', 'collider bias', 'normal counterfactual question', 'average treatment effect on treated', 'natural direct effect' or 'natural indirect effect'. Your answer should only be a term from the list above, enclosed in 'quotation marks'.
# conditional probability
# Step 3) Formalize the query: Translate the query into its formal mathematical expression based on its type, utilizing the 'do(·)' notation or counterfactual notations as needed.
# P(prisoner_death | captain_order = execute)
# Step 4) Gather all relevant data: Extract all the available data. Your answer should contain nothing but marginal probabilities and conditional probabilities in the form 'P(...)=...' or 'P(...|...)=...', each probability being separated by a semicolon. Stick to the previously mentioned denotations for the variables.
# P(captain_order = execute) = 0.18; P(captain_order = release) = 0.82; P(prisoner_death | captain_order = execute) = 0.81; P(prisoner_death | captain_order = release) = 0.33; P(prisoner_outcome | captain_order = execute) = 1; P(prisoner_outcome | captain_order = release) = 1
# Step 5) Deduce the estimand using causal inference: Given all the information above, deduce the estimand using skills such as do-calculus, counterfactual prediction, and the basics of probabilities.
# P(prisoner_death) > 0.5
# Step 6) Calculate the estimand: Insert the relevant data in Step 4 into the estimand, perform basic arithmetic calculations, and derive the final answer. Answer with yes or no in the end
# no
#
# -------
#
# PROMPT ANSWER:  Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# The overall probability of the captain's order to execute the prisoner is 18%. For captains who release prisoners, the probability of the prisoner's death is 33%. For captains who execute prisoners, the probability of the prisoner's death is 81%. Is the prisoner's death more likely than the prisoner being alive overall?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# captain_order -> prisoner_outcome, prisoner_outcome -> prisoner_death
# Step 2) Determine the query type: Identify the type of query implied by the main question. Choices include 'marginal probability', 'conditional probability', 'explaining away effect', 'backdoor adjustment set', 'average treatment effect', 'collider bias', 'normal counterfactual question', 'average treatment effect on treated', 'natural direct effect' or 'natural indirect effect'. Your answer should only be a term from the list above, enclosed in 'quotation marks'.
# conditional probability
# Step 3) Formalize the query: Translate the query into its formal mathematical expression based on its type, utilizing the 'do(·)' notation or counterfactual notations as needed.
# P(prisoner_death | captain_order = execute)
# Step 4) Gather all relevant data: Extract all the available data. Your answer should contain nothing but marginal probabilities and conditional probabilities in the form 'P(...)=...' or 'P(...|...)=...', each probability being separated by a semicolon. Stick to the previously mentioned denotations for the variables.
# P(captain_order = execute) = 0.18; P(captain_order = release) = 0.82; P(prisoner_death | captain_order = execute) = 0.81; P(prisoner_death | captain_order = release) = 0.33; P(prisoner_outcome | captain_order = execute) = 1; P(prisoner_outcome | captain_order = release) = 1
# Step 5) Deduce the estimand using causal inference: Given all the information above, deduce the estimand using skills such as do-calculus, counterfactual prediction, and the basics of probabilities.
# P(prisoner_death) > 0.5
# Step 6) Calculate the estimand: Insert the relevant data in Step 4 into the estimand, perform basic arithmetic calculations, and derive the final answer. Answer with yes or no in the end
# no
# EXTRACTED ANSWER:  no
# Generation completed:  252
# STEP NUMBER:  0
# Answer prompt:  Options: {"Citrus -> Scurvy", "Citrus -> No Scurvy", "Citrus intake affects Scurvy probability"}
# (Step 1) New Thoughts:  ['Citrus -> Scurvy', 'Citrus -> No Scurvy', 'Citrus intake affects Scurvy probability']
# (Step 1) ids  [0, 1, 2]
# Evaluate prompt:  Options: {"3", "7", "10"}
# (Step 2) Scores:  [3, 7, 10]
# (Step 3) Selected thought:  ['Citrus intake affects Scurvy probability']
# QUESTION SO FAR:  Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# For patients not consuming citrus, the probability of scurvy is 68%. For patients consuming citrus, the probability of scurvy is 53%. Will citrus intake decrease the chance of scurvy?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# Citrus intake affects Scurvy probability
#
# -------
#
# STEP NUMBER:  1
# Answer prompt:  Citrus intake affects Scurvy probability -> "average treatment effect" Options: {"marginal probability", "conditional probability", "average treatment effect"}
# (Step 1) New Thoughts:  ['marginal probability', 'conditional probability', 'average treatment effect']
# (Step 1) ids  [0, 1, 2]
# Evaluate prompt:  Citrus intake -> Scurvy probability, Scurvy probability -> scurvy
# Options: {"7", "8", "6"}
# (Step 2) Scores:  [7, 8, 6]
# (Step 3) Selected thought:  ['conditional probability']
# QUESTION SO FAR:  Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# For patients not consuming citrus, the probability of scurvy is 68%. For patients consuming citrus, the probability of scurvy is 53%. Will citrus intake decrease the chance of scurvy?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# Citrus intake affects Scurvy probability
# Step 2) Determine the query type: Identify the type of query implied by the main question. Choices include 'marginal probability', 'conditional probability', 'explaining away effect', 'backdoor adjustment set', 'average treatment effect', 'collider bias', 'normal counterfactual question', 'average treatment effect on treated', 'natural direct effect' or 'natural indirect effect'. Your answer should only be a term from the list above, enclosed in 'quotation marks'.
# conditional probability
#
# -------
#
# STEP NUMBER:  2
# Answer prompt:  Options: {"P(Scurvy | Citrus = Yes)", "P(Scurvy | Citrus = No)", "P(Scurvy | Citrus = Yes) - P(Scurvy | Citrus = No)"}
# (Step 1) New Thoughts:  ['P(Scurvy | Citrus = Yes)', 'P(Scurvy | Citrus = No)', 'P(Scurvy | Citrus = Yes) - P(Scurvy | Citrus = No)']
# (Step 1) ids  [0, 1, 2]
# Evaluate prompt:  Citrus intake affects Scurvy probability, Citrus -> Scurvy
#
# Options: {"8", "8", "10"}
# (Step 2) Scores:  [8, 8, 10]
# (Step 3) Selected thought:  ['P(Scurvy | Citrus = Yes) - P(Scurvy | Citrus = No)']
# QUESTION SO FAR:  Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# For patients not consuming citrus, the probability of scurvy is 68%. For patients consuming citrus, the probability of scurvy is 53%. Will citrus intake decrease the chance of scurvy?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# Citrus intake affects Scurvy probability
# Step 2) Determine the query type: Identify the type of query implied by the main question. Choices include 'marginal probability', 'conditional probability', 'explaining away effect', 'backdoor adjustment set', 'average treatment effect', 'collider bias', 'normal counterfactual question', 'average treatment effect on treated', 'natural direct effect' or 'natural indirect effect'. Your answer should only be a term from the list above, enclosed in 'quotation marks'.
# conditional probability
# Step 3) Formalize the query: Translate the query into its formal mathematical expression based on its type, utilizing the 'do(·)' notation or counterfactual notations as needed.
# P(Scurvy | Citrus = Yes) - P(Scurvy | Citrus = No)
#
# -------
#
# STEP NUMBER:  3
# SKIPPING THIS STEP:  3
# Single generate prompt:
# Question: Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# For patients not consuming citrus, the probability of scurvy is 68%. For patients consuming citrus, the probability of scurvy is 53%. Will citrus intake decrease the chance of scurvy?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# Citrus intake affects Scurvy probability
# Step 2) Determine the query type: Identify the type of query implied by the main question. Choices include 'marginal probability', 'conditional probability', 'explaining away effect', 'backdoor adjustment set', 'average treatment effect', 'collider bias', 'normal counterfactual question', 'average treatment effect on treated', 'natural direct effect' or 'natural indirect effect'. Your answer should only be a term from the list above, enclosed in 'quotation marks'.
# conditional probability
# Step 3) Formalize the query: Translate the query into its formal mathematical expression based on its type, utilizing the 'do(·)' notation or counterfactual notations as needed.
# P(Scurvy | Citrus = Yes) - P(Scurvy | Citrus = No) -> Step 4) Gather all relevant data: Extract all the available data. Your answer should contain nothing but marginal probabilities and conditional probabilities in the form 'P(...)=...' or 'P(...|...)=...', each probability being separated by a semicolon. Stick to the previously mentioned denotations for the variables. -> Answer this and put it in curly brackets like Answer: {X}
#
# Single answer prompt:  Answer: {P(Scurvy | Citrus = Yes) = 0.53; P(Scurvy | Citrus = No) = 0.68}
# Single answers thought:  P(Scurvy | Citrus = Yes) = 0.53; P(Scurvy | Citrus = No) = 0.68
# QUESTION SO FAR:  Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# For patients not consuming citrus, the probability of scurvy is 68%. For patients consuming citrus, the probability of scurvy is 53%. Will citrus intake decrease the chance of scurvy?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# Citrus intake affects Scurvy probability
# Step 2) Determine the query type: Identify the type of query implied by the main question. Choices include 'marginal probability', 'conditional probability', 'explaining away effect', 'backdoor adjustment set', 'average treatment effect', 'collider bias', 'normal counterfactual question', 'average treatment effect on treated', 'natural direct effect' or 'natural indirect effect'. Your answer should only be a term from the list above, enclosed in 'quotation marks'.
# conditional probability
# Step 3) Formalize the query: Translate the query into its formal mathematical expression based on its type, utilizing the 'do(·)' notation or counterfactual notations as needed.
# P(Scurvy | Citrus = Yes) - P(Scurvy | Citrus = No)
# Step 4) Gather all relevant data: Extract all the available data. Your answer should contain nothing but marginal probabilities and conditional probabilities in the form 'P(...)=...' or 'P(...|...)=...', each probability being separated by a semicolon. Stick to the previously mentioned denotations for the variables.
# P(Scurvy | Citrus = Yes) = 0.53; P(Scurvy | Citrus = No) = 0.68
#
# -------
#
# STEP NUMBER:  4
# Answer prompt:  Options: {"P(Scurvy | Citrus = Yes) - P(Scurvy | Citrus = No) = 0.53 - 0.68", "P(Scurvy | Citrus = No) > P(Scurvy | Citrus = Yes)", "Citrus intake decreases the chance of scurvy by 15%"}
# (Step 1) New Thoughts:  ['P(Scurvy | Citrus = Yes) - P(Scurvy | Citrus = No) = 0.53 - 0.68', 'P(Scurvy | Citrus = No) > P(Scurvy | Citrus = Yes)', 'Citrus intake decreases the chance of scurvy by 15%']
# (Step 1) ids  [0, 1, 2]
# Evaluate prompt:  Options: {"8", "9", "10"}
# (Step 2) Scores:  [8, 9, 10]
# (Step 3) Selected thought:  ['Citrus intake decreases the chance of scurvy by 15%']
# QUESTION SO FAR:  Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# For patients not consuming citrus, the probability of scurvy is 68%. For patients consuming citrus, the probability of scurvy is 53%. Will citrus intake decrease the chance of scurvy?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# Citrus intake affects Scurvy probability
# Step 2) Determine the query type: Identify the type of query implied by the main question. Choices include 'marginal probability', 'conditional probability', 'explaining away effect', 'backdoor adjustment set', 'average treatment effect', 'collider bias', 'normal counterfactual question', 'average treatment effect on treated', 'natural direct effect' or 'natural indirect effect'. Your answer should only be a term from the list above, enclosed in 'quotation marks'.
# conditional probability
# Step 3) Formalize the query: Translate the query into its formal mathematical expression based on its type, utilizing the 'do(·)' notation or counterfactual notations as needed.
# P(Scurvy | Citrus = Yes) - P(Scurvy | Citrus = No)
# Step 4) Gather all relevant data: Extract all the available data. Your answer should contain nothing but marginal probabilities and conditional probabilities in the form 'P(...)=...' or 'P(...|...)=...', each probability being separated by a semicolon. Stick to the previously mentioned denotations for the variables.
# P(Scurvy | Citrus = Yes) = 0.53; P(Scurvy | Citrus = No) = 0.68
# Step 5) Deduce the estimand using causal inference: Given all the information above, deduce the estimand using skills such as do-calculus, counterfactual prediction, and the basics of probabilities.
# Citrus intake decreases the chance of scurvy by 15%
#
# -------
#
# STEP NUMBER:  5
# SKIPPING THIS STEP:  5
# Single generate prompt:
# Question: Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# For patients not consuming citrus, the probability of scurvy is 68%. For patients consuming citrus, the probability of scurvy is 53%. Will citrus intake decrease the chance of scurvy?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# Citrus intake affects Scurvy probability
# Step 2) Determine the query type: Identify the type of query implied by the main question. Choices include 'marginal probability', 'conditional probability', 'explaining away effect', 'backdoor adjustment set', 'average treatment effect', 'collider bias', 'normal counterfactual question', 'average treatment effect on treated', 'natural direct effect' or 'natural indirect effect'. Your answer should only be a term from the list above, enclosed in 'quotation marks'.
# conditional probability
# Step 3) Formalize the query: Translate the query into its formal mathematical expression based on its type, utilizing the 'do(·)' notation or counterfactual notations as needed.
# P(Scurvy | Citrus = Yes) - P(Scurvy | Citrus = No)
# Step 4) Gather all relevant data: Extract all the available data. Your answer should contain nothing but marginal probabilities and conditional probabilities in the form 'P(...)=...' or 'P(...|...)=...', each probability being separated by a semicolon. Stick to the previously mentioned denotations for the variables.
# P(Scurvy | Citrus = Yes) = 0.53; P(Scurvy | Citrus = No) = 0.68
# Step 5) Deduce the estimand using causal inference: Given all the information above, deduce the estimand using skills such as do-calculus, counterfactual prediction, and the basics of probabilities.
# Citrus intake decreases the chance of scurvy by 15% -> Step 6) Calculate the estimand: Insert the relevant data in Step 4 into the estimand, perform basic arithmetic calculations, and derive the final answer. Answer with yes or no in the end -> Answer this and put it in curly brackets like Answer: {X}
#
# Single answer prompt:  To summarize and answer the question step by step using the provided framework:
#
# **Step 1: Extract the causal graph**
# Causal graph: **Citrus intake -> Scurvy**
#
# **Step 2: Determine the query type**
# Query type: **"conditional probability"**
#
# **Step 3: Formalize the query**
# Formal query expression: **P(Scurvy | Citrus = Yes) - P(Scurvy | Citrus = No)**
#
# **Step 4: Gather all relevant data**
# Relevant data:
# P(Scurvy | Citrus = Yes) = 0.53;
# P(Scurvy | Citrus = No) = 0.68
#
# **Step 5: Deduce the estimand using causal inference**
# Estimand deduced: **Citrus intake decreases the chance of scurvy by 15%**
#
# **Step 6: Calculate the estimand**
# Calculation:
# Difference = P(Scurvy | Citrus = No) - P(Scurvy | Citrus = Yes)
# Difference = 0.68 - 0.53 = 0.15 = 15%
#
# Since citrus intake results in a lower probability of scurvy (0.53 vs 0.68), it does decrease the chance of scurvy.
#
# Final answer: **Answer: {yes}**
# Single answers thought:  yes
# QUESTION SO FAR:  Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# For patients not consuming citrus, the probability of scurvy is 68%. For patients consuming citrus, the probability of scurvy is 53%. Will citrus intake decrease the chance of scurvy?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# Citrus intake affects Scurvy probability
# Step 2) Determine the query type: Identify the type of query implied by the main question. Choices include 'marginal probability', 'conditional probability', 'explaining away effect', 'backdoor adjustment set', 'average treatment effect', 'collider bias', 'normal counterfactual question', 'average treatment effect on treated', 'natural direct effect' or 'natural indirect effect'. Your answer should only be a term from the list above, enclosed in 'quotation marks'.
# conditional probability
# Step 3) Formalize the query: Translate the query into its formal mathematical expression based on its type, utilizing the 'do(·)' notation or counterfactual notations as needed.
# P(Scurvy | Citrus = Yes) - P(Scurvy | Citrus = No)
# Step 4) Gather all relevant data: Extract all the available data. Your answer should contain nothing but marginal probabilities and conditional probabilities in the form 'P(...)=...' or 'P(...|...)=...', each probability being separated by a semicolon. Stick to the previously mentioned denotations for the variables.
# P(Scurvy | Citrus = Yes) = 0.53; P(Scurvy | Citrus = No) = 0.68
# Step 5) Deduce the estimand using causal inference: Given all the information above, deduce the estimand using skills such as do-calculus, counterfactual prediction, and the basics of probabilities.
# Citrus intake decreases the chance of scurvy by 15%
# Step 6) Calculate the estimand: Insert the relevant data in Step 4 into the estimand, perform basic arithmetic calculations, and derive the final answer. Answer with yes or no in the end
# yes
#
# -------
#
# PROMPT ANSWER:  Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# For patients not consuming citrus, the probability of scurvy is 68%. For patients consuming citrus, the probability of scurvy is 53%. Will citrus intake decrease the chance of scurvy?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# Citrus intake affects Scurvy probability
# Step 2) Determine the query type: Identify the type of query implied by the main question. Choices include 'marginal probability', 'conditional probability', 'explaining away effect', 'backdoor adjustment set', 'average treatment effect', 'collider bias', 'normal counterfactual question', 'average treatment effect on treated', 'natural direct effect' or 'natural indirect effect'. Your answer should only be a term from the list above, enclosed in 'quotation marks'.
# conditional probability
# Step 3) Formalize the query: Translate the query into its formal mathematical expression based on its type, utilizing the 'do(·)' notation or counterfactual notations as needed.
# P(Scurvy | Citrus = Yes) - P(Scurvy | Citrus = No)
# Step 4) Gather all relevant data: Extract all the available data. Your answer should contain nothing but marginal probabilities and conditional probabilities in the form 'P(...)=...' or 'P(...|...)=...', each probability being separated by a semicolon. Stick to the previously mentioned denotations for the variables.
# P(Scurvy | Citrus = Yes) = 0.53; P(Scurvy | Citrus = No) = 0.68
# Step 5) Deduce the estimand using causal inference: Given all the information above, deduce the estimand using skills such as do-calculus, counterfactual prediction, and the basics of probabilities.
# Citrus intake decreases the chance of scurvy by 15%
# Step 6) Calculate the estimand: Insert the relevant data in Step 4 into the estimand, perform basic arithmetic calculations, and derive the final answer. Answer with yes or no in the end
# yes
# EXTRACTED ANSWER:  yes
# Generation completed:  253
# STEP NUMBER:  0
# Answer prompt:  Options: {"captain_order -> prisoner_outcome", "captain_order -> captain_action", "captain_action -> prisoner_outcome"}
# (Step 1) New Thoughts:  ['captain_order -> prisoner_outcome', 'captain_order -> captain_action', 'captain_action -> prisoner_outcome']
# (Step 1) ids  [0, 1, 2]
# Evaluate prompt:  Options: {"3", "5", "10"}
# (Step 2) Scores:  [3, 5, 10]
# (Step 3) Selected thought:  ['captain_action -> prisoner_outcome']
# QUESTION SO FAR:  Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# The overall probability of the captain's order to execute the prisoner is 69%. For captains who release prisoners, the probability of the prisoner's death is 23%. For captains who execute prisoners, the probability of the prisoner's death is 64%. Is the prisoner's death more likely than the prisoner being alive overall?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# captain_action -> prisoner_outcome
#
# -------
#
# STEP NUMBER:  1
# Answer prompt:  Options: {"marginal probability", "conditional probability", "average treatment effect"}
# (Step 1) New Thoughts:  ['marginal probability', 'conditional probability', 'average treatment effect']
# (Step 1) ids  [0, 1, 2]
# Evaluate prompt:  captain_action -> prisoner_outcome -> Options: ['marginal probability', 'conditional probability', 'average treatment effect'] ->
# -> Assign a score between 1 - 10 for each option in Options: depending on how well it answers the question (10 being the highest or the best), then put the score into a list, each score being a string, like Options: {"X", "X", "X"}. Make sure this is in a single line!
#
# Options: {"6", "9", "7"}
# (Step 2) Scores:  [6, 9, 7]
# (Step 3) Selected thought:  ['conditional probability']
# QUESTION SO FAR:  Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# The overall probability of the captain's order to execute the prisoner is 69%. For captains who release prisoners, the probability of the prisoner's death is 23%. For captains who execute prisoners, the probability of the prisoner's death is 64%. Is the prisoner's death more likely than the prisoner being alive overall?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# captain_action -> prisoner_outcome
# Step 2) Determine the query type: Identify the type of query implied by the main question. Choices include 'marginal probability', 'conditional probability', 'explaining away effect', 'backdoor adjustment set', 'average treatment effect', 'collider bias', 'normal counterfactual question', 'average treatment effect on treated', 'natural direct effect' or 'natural indirect effect'. Your answer should only be a term from the list above, enclosed in 'quotation marks'.
# conditional probability
#
# -------
#
# STEP NUMBER:  2
# Answer prompt:  Options: {"P(prisoner_death | captain_action = execute)", "P(prisoner_death | captain_action = release)", "P(prisoner_death | do(captain_action = execute))"}
# (Step 1) New Thoughts:  ['P(prisoner_death | captain_action = execute)', 'P(prisoner_death | captain_action = release)', 'P(prisoner_death | do(captain_action = execute))']
# (Step 1) ids  [0, 1, 2]
# Evaluate prompt:  Options: {"10", "8", "9"}
# (Step 2) Scores:  [10, 8, 9]
# (Step 3) Selected thought:  ['P(prisoner_death | captain_action = execute)']
# QUESTION SO FAR:  Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# The overall probability of the captain's order to execute the prisoner is 69%. For captains who release prisoners, the probability of the prisoner's death is 23%. For captains who execute prisoners, the probability of the prisoner's death is 64%. Is the prisoner's death more likely than the prisoner being alive overall?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# captain_action -> prisoner_outcome
# Step 2) Determine the query type: Identify the type of query implied by the main question. Choices include 'marginal probability', 'conditional probability', 'explaining away effect', 'backdoor adjustment set', 'average treatment effect', 'collider bias', 'normal counterfactual question', 'average treatment effect on treated', 'natural direct effect' or 'natural indirect effect'. Your answer should only be a term from the list above, enclosed in 'quotation marks'.
# conditional probability
# Step 3) Formalize the query: Translate the query into its formal mathematical expression based on its type, utilizing the 'do(·)' notation or counterfactual notations as needed.
# P(prisoner_death | captain_action = execute)
#
# -------
#
# STEP NUMBER:  3
# SKIPPING THIS STEP:  3
# Single generate prompt:
# Question: Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# ...
# marginal probability
# Step 3) Formalize the query: Translate the query into its formal mathematical expression based on its type, utilizing the 'do(·)' notation or counterfactual notations as needed.
# P(High Salary | College Degree or Higher) - P(High Salary)
# Step 4) Gather all relevant data: Extract all the available data. Your answer should contain nothing but marginal probabilities and conditional probabilities in the form 'P(...)=...' or 'P(...|...)=...', each probability being separated by a semicolon. Stick to the previously mentioned denotations for the variables.
# P(High Salary)=0.18; P(High Salary | College Degree or Higher)=0.22; P(College Degree or Higher)=0.42
#
# -------
#
# STEP NUMBER:  4
# Answer prompt:  Options: {"High salary is larger with college degree or higher", "High salary is smaller with college degree or higher", "High salary is the same regardless of college degree or higher"}
# (Step 1) New Thoughts:  ['High salary is larger with college degree or higher', 'High salary is smaller with college degree or higher', 'High salary is the same regardless of college degree or higher']
# (Step 1) ids  [0, 1, 2]
# Evaluate prompt:  Options: {"3", "9", "5"}
# (Step 2) Scores:  [3, 9, 5]
# (Step 3) Selected thought:  ['High salary is smaller with college degree or higher']
# QUESTION SO FAR:  Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# The overall probability of college degree or higher is 42%. The probability of high school degree or lower and high salary is 18%. The probability of college degree or higher and high salary is 22%. Is the chance of high salary smaller when observing college degree or higher?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# High School Degree or Lower -> High Salary
# Step 2) Determine the query type: Identify the type of query implied by the main question. Choices include 'marginal probability', 'conditional probability', 'explaining away effect', 'backdoor adjustment set', 'average treatment effect', 'collider bias', 'normal counterfactual question', 'average treatment effect on treated', 'natural direct effect' or 'natural indirect effect'. Your answer should only be a term from the list above, enclosed in 'quotation marks'.
# marginal probability
# Step 3) Formalize the query: Translate the query into its formal mathematical expression based on its type, utilizing the 'do(·)' notation or counterfactual notations as needed.
# P(High Salary | College Degree or Higher) - P(High Salary)
# Step 4) Gather all relevant data: Extract all the available data. Your answer should contain nothing but marginal probabilities and conditional probabilities in the form 'P(...)=...' or 'P(...|...)=...', each probability being separated by a semicolon. Stick to the previously mentioned denotations for the variables.
# P(High Salary)=0.18; P(High Salary | College Degree or Higher)=0.22; P(College Degree or Higher)=0.42
# Step 5) Deduce the estimand using causal inference: Given all the information above, deduce the estimand using skills such as do-calculus, counterfactual prediction, and the basics of probabilities.
# High salary is smaller with college degree or higher
#
# -------
#
# STEP NUMBER:  5
# SKIPPING THIS STEP:  5
# Single generate prompt:
# Question: Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# The overall probability of college degree or higher is 42%. The probability of high school degree or lower and high salary is 18%. The probability of college degree or higher and high salary is 22%. Is the chance of high salary smaller when observing college degree or higher?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# High School Degree or Lower -> High Salary
# Step 2) Determine the query type: Identify the type of query implied by the main question. Choices include 'marginal probability', 'conditional probability', 'explaining away effect', 'backdoor adjustment set', 'average treatment effect', 'collider bias', 'normal counterfactual question', 'average treatment effect on treated', 'natural direct effect' or 'natural indirect effect'. Your answer should only be a term from the list above, enclosed in 'quotation marks'.
# marginal probability
# Step 3) Formalize the query: Translate the query into its formal mathematical expression based on its type, utilizing the 'do(·)' notation or counterfactual notations as needed.
# P(High Salary | College Degree or Higher) - P(High Salary)
# Step 4) Gather all relevant data: Extract all the available data. Your answer should contain nothing but marginal probabilities and conditional probabilities in the form 'P(...)=...' or 'P(...|...)=...', each probability being separated by a semicolon. Stick to the previously mentioned denotations for the variables.
# P(High Salary)=0.18; P(High Salary | College Degree or Higher)=0.22; P(College Degree or Higher)=0.42
# Step 5) Deduce the estimand using causal inference: Given all the information above, deduce the estimand using skills such as do-calculus, counterfactual prediction, and the basics of probabilities.
# High salary is smaller with college degree or higher -> Step 6) Calculate the estimand: Insert the relevant data in Step 4 into the estimand, perform basic arithmetic calculations, and derive the final answer. Answer with yes or no in the end -> Answer this and put it in curly brackets like Answer: {X}
#
# Single answer prompt:  To analyze the scenario step-by-step:
#
# **Step 1:** The causal graph has identified the relationship:
# - High School Degree or Lower -> High Salary
#
# **Step 2:** The type of query asked is related to comparing probabilities, indicating it's a conditional probability, thus:
# - Query Type: "conditional probability"
#
# **Step 3:** The query formalized into a mathematical expression examines whether the chance of high salary is smaller when observing a college degree or higher:
# - Query: P(High Salary | College Degree or Higher) - P(High Salary)
#
# **Step 4:** The data extracted includes the following probabilities:
# - P(High Salary)=0.18; P(High Salary | College Degree or Higher)=0.22; P(College Degree or Higher)=0.42
#
# **Step 5:** To deduce the estimand, we consider the results of the conditional probability compared with the marginal probability:
# - High Salary with College Degree or Higher = 0.22
# - High Salary overall = 0.18
#
# **Step 6:** Now, we calculate:
# - P(High Salary | College Degree or Higher) = 0.22
# - P(High Salary) = 0.18
# - The calculation for the comparison: 0.22 - 0.18 = 0.04
#
# Since 0.22 is greater than 0.18, the chance of high salary is **not** smaller when observing a college degree or higher.
#
# Final Answer: {no}
# Single answers thought:  no
# QUESTION SO FAR:  Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# The overall probability of college degree or higher is 42%. The probability of high school degree or lower and high salary is 18%. The probability of college degree or higher and high salary is 22%. Is the chance of high salary smaller when observing college degree or higher?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# High School Degree or Lower -> High Salary
# Step 2) Determine the query type: Identify the type of query implied by the main question. Choices include 'marginal probability', 'conditional probability', 'explaining away effect', 'backdoor adjustment set', 'average treatment effect', 'collider bias', 'normal counterfactual question', 'average treatment effect on treated', 'natural direct effect' or 'natural indirect effect'. Your answer should only be a term from the list above, enclosed in 'quotation marks'.
# marginal probability
# Step 3) Formalize the query: Translate the query into its formal mathematical expression based on its type, utilizing the 'do(·)' notation or counterfactual notations as needed.
# P(High Salary | College Degree or Higher) - P(High Salary)
# Step 4) Gather all relevant data: Extract all the available data. Your answer should contain nothing but marginal probabilities and conditional probabilities in the form 'P(...)=...' or 'P(...|...)=...', each probability being separated by a semicolon. Stick to the previously mentioned denotations for the variables.
# P(High Salary)=0.18; P(High Salary | College Degree or Higher)=0.22; P(College Degree or Higher)=0.42
# Step 5) Deduce the estimand using causal inference: Given all the information above, deduce the estimand using skills such as do-calculus, counterfactual prediction, and the basics of probabilities.
# High salary is smaller with college degree or higher
# Step 6) Calculate the estimand: Insert the relevant data in Step 4 into the estimand, perform basic arithmetic calculations, and derive the final answer. Answer with yes or no in the end
# no
#
# -------
#
# PROMPT ANSWER:  Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# The overall probability of college degree or higher is 42%. The probability of high school degree or lower and high salary is 18%. The probability of college degree or higher and high salary is 22%. Is the chance of high salary smaller when observing college degree or higher?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# High School Degree or Lower -> High Salary
# Step 2) Determine the query type: Identify the type of query implied by the main question. Choices include 'marginal probability', 'conditional probability', 'explaining away effect', 'backdoor adjustment set', 'average treatment effect', 'collider bias', 'normal counterfactual question', 'average treatment effect on treated', 'natural direct effect' or 'natural indirect effect'. Your answer should only be a term from the list above, enclosed in 'quotation marks'.
# marginal probability
# Step 3) Formalize the query: Translate the query into its formal mathematical expression based on its type, utilizing the 'do(·)' notation or counterfactual notations as needed.
# P(High Salary | College Degree or Higher) - P(High Salary)
# Step 4) Gather all relevant data: Extract all the available data. Your answer should contain nothing but marginal probabilities and conditional probabilities in the form 'P(...)=...' or 'P(...|...)=...', each probability being separated by a semicolon. Stick to the previously mentioned denotations for the variables.
# P(High Salary)=0.18; P(High Salary | College Degree or Higher)=0.22; P(College Degree or Higher)=0.42
# Step 5) Deduce the estimand using causal inference: Given all the information above, deduce the estimand using skills such as do-calculus, counterfactual prediction, and the basics of probabilities.
# High salary is smaller with college degree or higher
# Step 6) Calculate the estimand: Insert the relevant data in Step 4 into the estimand, perform basic arithmetic calculations, and derive the final answer. Answer with yes or no in the end
# no
# EXTRACTED ANSWER:  no
# Generation completed:  270
# STEP NUMBER:  0
# Answer prompt:  Options: {"taking the elevator -> penguin sadness", "taking the elevator -> penguin death", "penguin happiness -> penguin death"}
# (Step 1) New Thoughts:  ['taking the elevator -> penguin sadness', 'taking the elevator -> penguin death', 'penguin happiness -> penguin death']
# (Step 1) ids  [0, 1, 2]
# Evaluate prompt:  Options: {"8", "10", "10"}
# (Step 2) Scores:  [8, 10, 10]
# (Step 3) Selected thought:  ['taking the elevator -> penguin death']
# QUESTION SO FAR:  Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:
# We know that taking the elevator causes penguin saddness. taking the elevator or penguin happiness causes penguin death. Would the penguin dies if taking the elevator instead of taking the stairs?
# Step 1) Extract the causal graph: Identify the causal graph that depicts the relationships in the scenario. The diagram should simply consist of edges denoted in 'var1 -> var2' format, separated by commas.
# taking the elevator -> penguin death
#
# -------
#
# STEP NUMBER:  1
# Answer prompt:  Options: {"marginal probability", "conditional probability", "normal counterfactual question"}
# (Step 1) New Thoughts:  ['marginal probability', 'conditional probability', 'normal counterfactual question']
# (Step 1) ids  [0, 1, 2]
# Evaluate prompt:  Causal Graph: taking the elevator -> penguin sadness, taking the elevator -> penguin death, penguin happiness -> penguin death
#
# Options: ["7", "9", "8"]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 27
#      22         else:
#      24             print('Skipping: ', i)
# ---> 27 run_openai_tree_of_thoughts(df_cladder, model_col_name='gpt-4o-mini', model='gpt-4o-mini', overwrite=True, min_range=252, max_range=300)
#
# Cell In[80], line 11, in run_openai_tree_of_thoughts(df, model_col_name, model, min_range, max_range, temperature, overwrite)
#       8 if df.iloc[i][model_col_name] is None or overwrite == True:
#      10     prompt_question =  'Imagine a self-contained, hypothetical world with only the following conditions, and without any unmentioned factors or causal relationships:' + '\n' + df.iloc[i]['info'] + " " + df.iloc[i]['question']
# ---> 11     prompt_answer = tree_of_thoughts(model, prompt_question, 3, 1)
#      12     extracted_answer = extract_yes_or_no(prompt_answer)
#      15     print('PROMPT ANSWER: ', prompt_answer)
#
# Cell In[72], line 28, in tree_of_thoughts(model, question, num_generated_options, num_selected_options)
#      25 print('(Step 1) ids ', ids)
#      27 # Thought Evaluation
# ---> 28 scores = evaluate_thoughts(model, question, new_thoughts)
#      29 print('(Step 2) Scores: ', scores)
#      31 # Thought Selection (Search Algorithm) -> Here, we only select one highest scoring thought and progress
#      32 # to the next step
#
# Cell In[58], line 56, in evaluate_thoughts(model, question, new_thoughts)
#      53 print('Evaluate prompt: ', answer_prompt)
#      55 answer = extract_options(answer_prompt)
# ---> 56 integer_list = [int(x) for x in answer]
#      57 return integer_list
#
# TypeError: 'NoneType' object is not iterable

# %%
import datetime

# Save pickle
df_cladder.to_pickle('../data/log/cladder-tree_of_thoughts' + '-' + datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S") + '.pkl')

# Read pickle
#unpickled_df = pd.read_pickle('./cladder.pkl')
#df_cladder = unpickled_df

# %%
def generate_results(df, gt_column, pred_column):
    # Check if the ground truth and predicted columns exist in the DataFrame
    if gt_column not in df.columns or pred_column not in df.columns:
        print("Specified columns not found in the DataFrame.")
        return

    # Calculate accuracy by comparing the ground truth and predicted columns
    correct_predictions = (df[gt_column] == df[pred_column]).sum()
    total_predictions = len(df)
    accuracy = correct_predictions / total_predictions

    # Print accuracy as a percentage
    print(pred_column,f"accuracy: {accuracy * 100:.2f}%")


for c in column_names:
    generate_results(df_cladder, 'answer', c)
# Out:
# gpt-4o-mini accuracy: 17.80%

# %%
def generate_results(df, gt_column, pred_column):
    
    matching_rows = df[df[gt_column] == df[pred_column]]

    if len(df_cladder[df_cladder[pred_column].notna()]) != 0:  
        accuracy = len(matching_rows) / len(df_cladder[df_cladder[pred_column].notna()])
        print('Accuracy for ' + pred_column + ' : ' + str(accuracy * 100))
    else:
        print('Accuracy for ' + pred_column + ' : None made!')


for c in column_names:
    generate_results(df_cladder, 'answer', c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#       8     else:
#       9         print('Accuracy for ' + pred_column + ' : None made!')
# ---> 12 for c in column_names:
#      13     generate_results(df_cladder, 'answer', c)
#
# NameError: name 'column_names' is not defined

# %%
def generate_results(df, gt_column, pred_column):
    # Check if the ground truth and predicted columns exist in the DataFrame
    if gt_column not in df.columns or pred_column not in df.columns:
        print("Specified columns not found in the DataFrame.")
        return

    # Drop rows where either ground truth or prediction is None
    valid_df = df.dropna(subset=[gt_column, pred_column])

    # Calculate accuracy by comparing the ground truth and predicted columns
    correct_predictions = (valid_df[gt_column] == valid_df[pred_column]).sum()
    total_predictions = len(valid_df)
    accuracy = correct_predictions / total_predictions if total_predictions > 0 else 0

    # Print accuracy as a percentage
    print('Accuracy for ' + pred_column + f" : {accuracy * 100:.2f}%")

# Loop through each specified column name for predictions
for c in column_names:
    generate_results(df_cladder, 'answer', c)
